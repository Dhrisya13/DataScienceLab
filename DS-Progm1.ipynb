# %%
a=int(input("Enter the first number:"))
b=int(input("Enter the second number:"))
print("Addition=",a+b)
print("Subtraction=",a-b)
print("Multiplication=",a*b)
print("Division=",a/b)
print("Exponentiation:",a**b)
# Out:
# Enter the first number:8
# Enter the second number:4
# Addition= 12
# Subtraction= 4
# Multiplication= 32
# Division= 2.0
# Exponentiation: 4096

# %%
a=input("enter the values:")
b=input("enter another value:")
c=a + " " + b
print("concatenation:",c)
print("length of a:",len(a))
print("reverse of a:",a[::-1])
print("uppercase:",a.upper())
print("lowercase:",a.lower())
print("centered string:",a.center(10))
print("replaced value:",b.replace("Value","problem"))
# Out:
# enter the values:String
# enter another value:Value
# concatenation: String Value
# length of a: 6
# reverse of a: gnirtS
# uppercase: STRING
# lowercase: string
# centered string:   String
# replaced value: problem

# %%
a=[1,2,3,4,5,6,7,8]
print("value in position 1:",a[1])
print("reversed list value:",a[::-1])
print("value btw 2 to 7:",a[2:6])
print("sum:",sum(a))
a.append(9)
print("append value:",a)
print("pop value:",a.pop(4))
# Out:
# value in position 1: 2
# reversed list value: [8, 7, 6, 5, 4, 3, 2, 1]
# value btw 2 to 7: [3, 4, 5, 6]
# sum: 36
# append value: [1, 2, 3, 4, 5, 6, 7, 8, 9]
# pop value: 5

# %%
#loop
for i in range(6):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
i=0
while i<5:
    print(i)
    i+=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#Dictionaries
student={"name":"anu","age":22,"course":"mca"}
print(student["name"])
print(student.keys())
print(student.values())
# Out:
# anu
# dict_keys(['name', 'age', 'course'])
# dict_values(['anu', 22, 'mca'])

# %%
#set
s={1,2,3}
print(s)
s.add(4)
print(s)

#tuple
t=(10,20,30)
print("first position",t[0])

#function
def add(a,b):
    return a+b
print("function of a and b",add(4,6))
# Out:
# {1, 2, 3}
# {1, 2, 3, 4}
# first position 10
# function of a and b 10

# %%
#largest number from list
num=[4,50,2,66,1,35,7,50,4]
print("Largest number",max(num))
#remove duplicates
print("duplicate removed",list(set(num)))
# Out:
# Largest number 66
# duplicate removed [1, 2, 66, 4, 35, 7, 50]

# %%
#convert tuple to dictionary
t=(("a",1),("b",2),("c",3))
d=dict(t)
print(d)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
#merge two dictionary
t={"a":1,"b":2}
s={"c":3,"d":4}
print("merge value",t|s)
# Out:
# merge value {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
#common number
lst1=[1,2,3,4]
lst2=[3,4,5,6]
print("common values",set(lst1)&set(lst2))
# Out:
# common values {3, 4}
